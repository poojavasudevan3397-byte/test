# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import pandas as pd

DB_USER = "root"
DB_PASSWORD = quote_plus("Vasu@76652")
DB_HOST = "localhost"
DB_PORT = 3306
DB_NAME = "cricketdb"

engine = create_engine(
    f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

#import pandas as pd

query = """
SELECT *
FROM players
ORDER BY player_name
LIMIT 100;
"""

df_players = pd.read_sql(query, engine)

# %%
#pip install pymysql sqlalchemy pandas ipython-sql mysql-connector-python
#pip install Pylance
# Out:
#   Cell In[2], line 2
#     pip install Pylance
#         ^
# SyntaxError: invalid syntax

# %%
df_players
# Out:
#       id external_player_id         player_name date_of_birth country role  \
# 0   1744              13170        Aaron Hardie          None
# 1   1516               9716  Abhimanyu Easwaran          None
# 2   1521              12086     Abhishek Sharma          None
# 3   1752               8642          Adam Zampa          None
# 4   1788               1742         Adil Rashid          None
# ..   ...                ...                 ...           ...     ...  ...
# 95  1486              14565        Marco Jansen          None
# 96  2795               9182      Marizanne Kapp          None
# 97  1795               9976        Mark Chapman          None
# 98  1784               8383           Mark Wood          None
# 99  1737              10182  Marnus Labuschagne          None
#
#                                                  meta          created_at
# 0   {"image_id": "619878", "batting_style": "Right... 2025-12-19 06:35:49
# 1   {"image_id": "591956", "batting_style": "Right... 2025-12-14 23:28:19
# 2   {"image_id": "153963", "batting_style": "Left-... 2025-12-14 23:28:19
# 3   {"image_id": "619887", "batting_style": "Right... 2025-12-19 06:35:49
# 4   {"image_id": "617413", "batting_style": "Right... 2025-12-19 06:35:50
# ..                                                ...                 ...
# 95  {"image_id": "619862", "batting_style": "Right... 2025-12-14 23:28:18
# 96  {"image_id": "767132", "batting_style": "Right... 2025-12-20 02:11:31
# 97  {"image_id": "616435", "batting_style": "Left-... 2025-12-19 06:35:52
# 98  {"image_id": "617415", "batting_style": "Right... 2025-12-19 06:35:50
# 99  {"image_id": "619875", "batting_style": "Right... 2025-12-19 06:35:49
#
# [100 rows x 8 columns]
